# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("playlist_2010to2022.csv")

# %%
data.head()
# Out:
#                                         playlist_url  year  \
# 0  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 1  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 2  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 3  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 4  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
#
#                  track_id            track_name  track_popularity  \
# 0  3AJwUDP919kvQ9QcozQPxg                Yellow                91
# 1  2m1hi0nfMR9vdGC8UcrnwU  All The Small Things                84
# 2  3y4LxiYMgDl4RethdzpmNe               Breathe                69
# 3  60a0Rd6pjrkxjPbaKzXjfq            In the End                88
# 4  62bOmKYxYg7dhrC6gH9vFn           Bye Bye Bye                74
#
#                            album               artist_id  artist_name  \
# 0                     Parachutes  4gzpq5DPGxSnKTe4SA8HAU     Coldplay
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2300 entries, 0 to 2299
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   playlist_url       2300 non-null   object
#  1   year               2300 non-null   int64
#  2   track_id           2300 non-null   object
#  3   track_name         2300 non-null   object
#  4   track_popularity   2300 non-null   int64
#  5   album              2300 non-null   object
#  6   artist_id          2300 non-null   object
#  7   artist_name        2300 non-null   object
#  8   artist_genres      2300 non-null   object
#  9   artist_popularity  2300 non-null   int64
#  10  danceability       2299 non-null   float64
#  11  energy             2299 non-null   float64
#  12  key                2299 non-null   float64
#  13  loudness           2299 non-null   float64
#  14  mode               2299 non-null   float64
#  15  speechiness        2299 non-null   float64
# ...

# %%
data.describe()
# Out:
#               year  track_popularity  artist_popularity  danceability  \
# count  2300.000000       2300.000000        2300.000000   2299.000000
# mean   2011.000000         70.943478          72.869565      0.660116
# std       6.634692         12.291526          12.179263      0.141137
# min    2000.000000          0.000000          29.000000      0.162000
# 25%    2005.000000         66.000000          65.000000      0.572000
# 50%    2011.000000         72.000000          74.000000      0.671000
# 75%    2017.000000         79.000000          82.000000      0.759500
# max    2022.000000        100.000000         100.000000      0.975000
#
#             energy          key     loudness         mode  speechiness  \
# count  2299.000000  2299.000000  2299.000000  2299.000000  2299.000000
# mean      0.693047     5.277947    -5.784040     0.598521     0.097795
# std       0.164838     3.628494     2.080853     0.490304     0.092445
# ...

# %%
loud = data.plot(kind="scatter", x="loudness", y="track_popularity", alpha=0.2)
loud.set_xlim(-9,-3)
# Out:
# (-9.0, -3.0)

# %%
en = data.plot(kind="scatter", x="energy", y="track_popularity", alpha=0.2)
en.set_xlim(0.4, 1)
# Out:
# (0.4, 1.0)

# %%
data.plot(kind ="bar", x="track_popularity", y=["danceability", "energy"])
# Out:
# <Axes: xlabel='track_popularity'>

# %%
sorted_data = data.sort_values(by='track_popularity', ascending=False)

data_top_five = sorted_data.head(5)

data_top_five.plot(kind ="bar", x="track_popularity", y=["danceability", "energy"])
# Out:
# <Axes: xlabel='track_popularity'>

# %%
temp = data.plot(kind="scatter", x="tempo", y="track_popularity", alpha=0.2)
temp.set_xlim(80, 140)
# Out:
# (80.0, 140.0)

# %%
dance = data.plot(kind="scatter", x="danceability", y="track_popularity", alpha=0.2)
dance.set_xlim(0.5, 0.9)
# Out:
# (0.5, 0.9)

# %% [markdown]
# ## Lab 2

# %%
import os
import tarfile
import urllib
import urllib.request

# %%
# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#Histograms

data.hist(bins=50, figsize=(30, 50))
plt.show()

# %%
data.plot(kind="scatter", x="track_popularity", y="artist_popularity")
# Out:
# <Axes: xlabel='track_popularity', ylabel='artist_popularity'>

# %%
data.plot(kind="scatter", x="energy", y="track_popularity",
    s=data["artist_popularity"], label="artist_popularity", figsize=(10,7), alpha=0.4, 
    c="artist_popularity", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()

# %%
data.plot(kind="scatter", x="danceability", y="track_popularity",
    s=data["artist_popularity"], label="artist_popularity", figsize=(10,7), alpha=0.4, 
    c="artist_popularity", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()

# %%
data2 = data.drop(["playlist_url", "track_id", "track_name", "album", "artist_id", "artist_name", "artist_genres"], axis=1)

corr_data = data2.corr()
corr_data
# Out:
#                        year  track_popularity  artist_popularity  \
# year               1.000000          0.218578           0.463891
# track_popularity   0.218578          1.000000           0.331063
# artist_popularity  0.463891          0.331063           1.000000
# danceability       0.079579          0.006881           0.028621
# energy            -0.213265         -0.074284          -0.108966
# key               -0.012309         -0.047865          -0.029549
# loudness          -0.087451         -0.018558          -0.029041
# mode              -0.008052          0.019854          -0.044217
# speechiness        0.026364         -0.027161           0.048929
# acousticness       0.144010          0.058311           0.061085
# instrumentalness  -0.071127         -0.020854          -0.073707
# liveness          -0.027719         -0.020033           0.004202
# valence           -0.192476         -0.067300          -0.125514
# ...

# %%
import seaborn as sns
plt.figure(figsize=(12, 10))
sns.heatmap(corr_data, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.show()

# %%
mdata = data[["track_popularity", "artist_popularity", "danceability", "energy", "loudness", "tempo"]]

# %%
mdata.head
# Out:
# <bound method NDFrame.head of       track_popularity  artist_popularity  danceability  energy  loudness  \
# 0                   91                 86         0.429   0.661    -7.227
# 1                   84                 75         0.434   0.897    -4.918
# 2                   69                 61         0.529   0.496    -9.007
# 3                   88                 83         0.556   0.864    -5.870
# 4                   74                 65         0.610   0.926    -4.843
# ...                ...                ...           ...     ...       ...
# 2295                79                 86         0.775   0.736    -8.072
# 2296                69                 85         0.937   0.793    -4.431
# 2297                86                 82         0.911   0.573    -7.430
# 2298                77                 84         0.773   0.422    -4.572
# 2299                77                 78         0.376   0.657    -4.658
#
#         tempo
# 0     173.372
# 1     148.726
# ...

# %%
corr = mdata.corr()
corr
# Out:
#                    track_popularity  artist_popularity  danceability  \
# track_popularity           1.000000           0.331063      0.006881
# artist_popularity          0.331063           1.000000      0.028621
# danceability               0.006881           0.028621      1.000000
# energy                    -0.074284          -0.108966     -0.040575
# loudness                  -0.018558          -0.029041      0.028889
# tempo                     -0.013565          -0.009967     -0.193770
#
#                      energy  loudness     tempo
# track_popularity  -0.074284 -0.018558 -0.013565
# artist_popularity -0.108966 -0.029041 -0.009967
# danceability      -0.040575  0.028889 -0.193770
# energy             1.000000  0.691206  0.125645
# loudness           0.691206  1.000000  0.092811
# tempo              0.125645  0.092811  1.000000

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.show()
