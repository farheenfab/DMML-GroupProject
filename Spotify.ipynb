# %%
import pandas as pd 
import numpy as np

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import numpy as np

import seaborn as sn

# %%
df = pd.read_csv("playlist_2010to2022.csv")
df.head()
# Out:
#                                         playlist_url  year  \
# 0  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 1  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 2  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 3  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 4  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
#
#                  track_id            track_name  track_popularity  \
# 0  3AJwUDP919kvQ9QcozQPxg                Yellow                91
# 1  2m1hi0nfMR9vdGC8UcrnwU  All The Small Things                84
# 2  3y4LxiYMgDl4RethdzpmNe               Breathe                69
# 3  60a0Rd6pjrkxjPbaKzXjfq            In the End                88
# 4  62bOmKYxYg7dhrC6gH9vFn           Bye Bye Bye                74
#
#                            album               artist_id  artist_name  \
# 0                     Parachutes  4gzpq5DPGxSnKTe4SA8HAU     Coldplay
# ...

# %%
df.describe()
# Out:
#               year  track_popularity  artist_popularity  danceability  \
# count  2300.000000       2300.000000        2300.000000   2299.000000
# mean   2011.000000         70.943478          72.869565      0.660116
# std       6.634692         12.291526          12.179263      0.141137
# min    2000.000000          0.000000          29.000000      0.162000
# 25%    2005.000000         66.000000          65.000000      0.572000
# 50%    2011.000000         72.000000          74.000000      0.671000
# 75%    2017.000000         79.000000          82.000000      0.759500
# max    2022.000000        100.000000         100.000000      0.975000
#
#             energy          key     loudness         mode  speechiness  \
# count  2299.000000  2299.000000  2299.000000  2299.000000  2299.000000
# mean      0.693047     5.277947    -5.784040     0.598521     0.097795
# std       0.164838     3.628494     2.080853     0.490304     0.092445
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2300 entries, 0 to 2299
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   playlist_url       2300 non-null   object
#  1   year               2300 non-null   int64
#  2   track_id           2300 non-null   object
#  3   track_name         2300 non-null   object
#  4   track_popularity   2300 non-null   int64
#  5   album              2300 non-null   object
#  6   artist_id          2300 non-null   object
#  7   artist_name        2300 non-null   object
#  8   artist_genres      2300 non-null   object
#  9   artist_popularity  2300 non-null   int64
#  10  danceability       2299 non-null   float64
#  11  energy             2299 non-null   float64
#  12  key                2299 non-null   float64
#  13  loudness           2299 non-null   float64
#  14  mode               2299 non-null   float64
#  15  speechiness        2299 non-null   float64
# ...

# %%
df["key"].value_counts()
# Out:
# key
# 1.0     297
# 0.0     253
# 7.0     225
# 11.0    219
# 5.0     201
# 2.0     189
# 8.0     183
# 9.0     183
# 6.0     177
# 4.0     152
# 10.0    147
# 3.0      73
# Name: count, dtype: int64

# %%
df.isnull().sum(axis=0)
# Out:
# playlist_url         0
# year                 0
# track_id             0
# track_name           0
# track_popularity     0
# album                0
# artist_id            0
# artist_name          0
# artist_genres        0
# artist_popularity    0
# danceability         1
# energy               1
# key                  1
# loudness             1
# mode                 1
# speechiness          1
# acousticness         1
# instrumentalness     1
# liveness             1
# valence              1
# tempo                1
# duration_ms          1
# time_signature       1
# dtype: int64

# %%
df.plot(kind = "scatter", x = "artist_popularity", y = "track_popularity", alpha = 0.4)
# Out:
# <Axes: xlabel='artist_popularity', ylabel='track_popularity'>

# %%
pip install matplotlib.pyplot
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
pip install matplotlib.pyplot
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
df.hist(bins = 50 , figsize = (20,15))
plt.show()

# %%
df.plot(kind = "scatter", x = "artist_popularity", y = "track_popularity")
# Out:
# <Axes: xlabel='artist_popularity', ylabel='track_popularity'>

# %%
df.plot(kind = "scatter", x = "artist_popularity", y = "track_popularity",alpha=0.2)
# Out:
# <Axes: xlabel='artist_popularity', ylabel='track_popularity'>

# %%
df.plot(kind = "scatter", x = "artist_popularity", y = "track_popularity",alpha=0.2,c="tempo" , cmap=plt.get_cmap("jet"), colorbar=True)
# Out:
# <Axes: xlabel='artist_popularity', ylabel='track_popularity'>

# %%
corr_matrix = df.corr()
sn.heatmap(corr_matrix, annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Poornima\OneDrive - Heriot-Watt University\Desktop\dmml portfolio\DMML-GroupProject\Spotify.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Poornima/OneDrive%20-%20Heriot-Watt%20University/Desktop/dmml%20portfolio/DMML-GroupProject/Spotify.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> corr_matrix = df.corr()
#       <a href='vscode-notebook-cell:/c%3A/Users/Poornima/OneDrive%20-%20Heriot-Watt%20University/Desktop/dmml%20portfolio/DMML-GroupProject/Spotify.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> sn.heatmap(corr_matrix, annot=True)
#
# File c:\Users\Poornima\anaconda3\envs\F21DL\lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
# ...

# %%
numeric_df = df.select_dtypes(include='number')
numeric_df.head(10)
# Out:
#    year  track_popularity  artist_popularity  danceability  energy   key  \
# 0  2000                91                 86         0.429   0.661  11.0
# 1  2000                84                 75         0.434   0.897   0.0
# 2  2000                69                 61         0.529   0.496   7.0
# 3  2000                88                 83         0.556   0.864   3.0
# 4  2000                74                 65         0.610   0.926   8.0
# 5  2000                73                 56         0.706   0.888   2.0
# 6  2000                88                 88         0.949   0.661   5.0
# 7  2000                57                 69         0.712   0.762   7.0
# 8  2000                80                 69         0.713   0.678   5.0
# 9  2000                83                 80         0.458   0.795   0.0
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -7.227   1.0       0.0281       0.00239          0.000121    0.2340
# ...

# %%
corr_matrix = numeric_df.corr()
plt.figure(figsize=(20,20))
sn.set(rc={'figure.figsize':(11.7,8.27)})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Poornima\OneDrive - Heriot-Watt University\Desktop\dmml portfolio\DMML-GroupProject\Spotify.ipynb Cell 25 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Poornima/OneDrive%20-%20Heriot-Watt%20University/Desktop/dmml%20portfolio/DMML-GroupProject/Spotify.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> #corr_matrix = numeric_df.corr()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Poornima/OneDrive%20-%20Heriot-Watt%20University/Desktop/dmml%20portfolio/DMML-GroupProject/Spotify.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> corr_matrix = sn.load_dataset("playlist_2010to2022.csv")
#       <a href='vscode-notebook-cell:/c%3A/Users/Poornima/OneDrive%20-%20Heriot-Watt%20University/Desktop/dmml%20portfolio/DMML-GroupProject/Spotify.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> plt.figure(figsize=(20,20))
# ...

# %%
sn.heatmap(corr_matrix , annot=True, xticklabels=True, yticklabels=True, fmt=".2f")
# Out:
# <Axes: >

# %%
# Set the figure size for the heatmap
df.plot(kind="scatter", x="track_popularity", y="energy", alpha=0.4, label="population", figsize=(10,7),
    c="loudness", cmap=plt.get_cmap("jet"), colorbar=True,
)

#
# Out:
# <Axes: xlabel='track_popularity', ylabel='energy'>

# %%
df.plot(kind = "scatter", x = "acousticness", y = "energy")
# Out:
# <Axes: xlabel='acousticness', ylabel='energy'>

# %%
df.plot(kind = "scatter", x = "loudness", y = "energy")
# Out:
# <Axes: xlabel='loudness', ylabel='energy'>

# %%
corr_matrix
# Out:
#                        year  track_popularity  artist_popularity  \
# year               1.000000          0.218578           0.463891
# track_popularity   0.218578          1.000000           0.331063
# artist_popularity  0.463891          0.331063           1.000000
# danceability       0.079579          0.006881           0.028621
# energy            -0.213265         -0.074284          -0.108966
# key               -0.012309         -0.047865          -0.029549
# loudness          -0.087451         -0.018558          -0.029041
# mode              -0.008052          0.019854          -0.044217
# speechiness        0.026364         -0.027161           0.048929
# acousticness       0.144010          0.058311           0.061085
# instrumentalness  -0.071127         -0.020854          -0.073707
# liveness          -0.027719         -0.020033           0.004202
# valence           -0.192476         -0.067300          -0.125514
# ...

# %%
plt.style.use('default')
df.plot(kind = "scatter", x = "loudness", y = "danceability",alpha=0.2,c="energy" , cmap=plt.get_cmap("jet"), colorbar=True)
# Out:
# <Axes: xlabel='loudness', ylabel='danceability'>

# %%
#plt.figure(figsize=(20, 20))
plt.style.use('ggplot')
df.plot(kind = "scatter", x = "acousticness", y = "artist_popularity",c="track_popularity" ,alpha =0.5, cmap=plt.get_cmap("jet"), colorbar=True,figsize=(8,6))
plt.show()

# %%
plt.figure(figsize=(10, 8))
sn.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.style.use('ggplot')
df.plot(kind = "scatter", x = "acousticness", y = "energy", c="track_popularity",alpha =0.5, cmap=plt.get_cmap("jet"), colorbar=True,figsize=(8,6))

plt.show()

# %%
#data cleaning
#sample_incomplete_rows = housing[housing.isnull().any(axis=1)].head()

df_clean = df[df.isnull().any(axis=1)].head()
df_clean.head()
# Out:
#                                           playlist_url  year  \
# 447  https://open.spotify.com/playlist/37i9dQZF1DWT...  2004
#
#                    track_id   track_name  track_popularity      album  \
# 447  6MFQeWtk7kxWGydnJB2y36  These Words                68  Unwritten
#
#                   artist_id          artist_name  \
# 447  7o95ZoZt5ZYn31e9z1Hc0a  Natasha Bedingfield
#
#                              artist_genres  artist_popularity  ...  loudness  \
# 447  ['dance pop', 'pop', 'post-teen pop']                 64  ...       NaN
#
#      mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 447   NaN          NaN           NaN               NaN       NaN      NaN
#
#      tempo  duration_ms  time_signature
# 447    NaN          NaN             NaN
#
# [1 rows x 23 columns]

# %%
from pandas.plotting import scatter_matrix

attributes = ["loudness", "valence", "acousticness", "liveness","danceability","tempo"]
scatter_matrix(df[attributes], figsize=(12, 8))
# Out:
# array([[<Axes: xlabel='loudness', ylabel='loudness'>,
#         <Axes: xlabel='valence', ylabel='loudness'>,
#         <Axes: xlabel='acousticness', ylabel='loudness'>,
#         <Axes: xlabel='liveness', ylabel='loudness'>,
#         <Axes: xlabel='danceability', ylabel='loudness'>,
#         <Axes: xlabel='tempo', ylabel='loudness'>],
#        [<Axes: xlabel='loudness', ylabel='valence'>,
#         <Axes: xlabel='valence', ylabel='valence'>,
#         <Axes: xlabel='acousticness', ylabel='valence'>,
#         <Axes: xlabel='liveness', ylabel='valence'>,
#         <Axes: xlabel='danceability', ylabel='valence'>,
#         <Axes: xlabel='tempo', ylabel='valence'>],
#        [<Axes: xlabel='loudness', ylabel='acousticness'>,
#         <Axes: xlabel='valence', ylabel='acousticness'>,
#         <Axes: xlabel='acousticness', ylabel='acousticness'>,
#         <Axes: xlabel='liveness', ylabel='acousticness'>,
#         <Axes: xlabel='danceability', ylabel='acousticness'>,
# ...
