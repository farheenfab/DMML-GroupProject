# %% [markdown]
# # Lab 3 - Dataset Exploration

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Spotify Top Hit Playlist (2010-2022)
#
# (https://www.kaggle.com/datasets/josephinelsy/spotify-top-hit-playlist-2010-2022)

# %%
data1=pd.read_csv(r"C:\Users\Poornima\OneDrive - Heriot-Watt University\Desktop\dmml portfolio\DMML-GroupProject\playlist_2010to2022.csv")

# %%
data1.head()
# Out:
#                                         playlist_url  year  \
# 0  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 1  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 2  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 3  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 4  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
#
#                  track_id            track_name  track_popularity  \
# 0  3AJwUDP919kvQ9QcozQPxg                Yellow                91
# 1  2m1hi0nfMR9vdGC8UcrnwU  All The Small Things                84
# 2  3y4LxiYMgDl4RethdzpmNe               Breathe                69
# 3  60a0Rd6pjrkxjPbaKzXjfq            In the End                88
# 4  62bOmKYxYg7dhrC6gH9vFn           Bye Bye Bye                74
#
#                            album               artist_id  artist_name  \
# 0                     Parachutes  4gzpq5DPGxSnKTe4SA8HAU     Coldplay
# 1             Enema Of The State  6FBDaR13swtiWwGhX1WQsP    blink-182
# 2                        Breathe  25NQNriVT2YbSW80ILRWJa   Faith Hill
# 3  Hybrid Theory (Bonus Edition)  6XyY86QOPPrYVGvF9ch6wz  Linkin Park
# 4            No Strings Attached  6Ff53KvcvAj5U7Z1vojB5o       *NSYNC
#
#                                        artist_genres  artist_popularity  ...  \
# 0                          ['permanent wave', 'pop']                 86  ...
# 1  ['alternative metal', 'modern rock', 'pop punk...                 75  ...
# 2  ['contemporary country', 'country', 'country d...                 61  ...
# 3  ['alternative metal', 'nu metal', 'post-grunge...                 83  ...
# 4                   ['boy band', 'dance pop', 'pop']                 65  ...
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -7.227   1.0       0.0281       0.00239          0.000121    0.2340
# 1    -4.918   1.0       0.0488       0.01030          0.000000    0.6120
# 2    -9.007   1.0       0.0290       0.17300          0.000000    0.2510
# 3    -5.870   0.0       0.0584       0.00958          0.000000    0.2090
# 4    -4.843   0.0       0.0479       0.03100          0.001200    0.0821
#
#    valence    tempo  duration_ms  time_signature
# 0    0.285  173.372     266773.0             4.0
# 1    0.684  148.726     167067.0             4.0
# 2    0.278  136.859     250547.0             4.0
# 3    0.400  105.143     216880.0             4.0
# 4    0.861  172.638     200400.0             4.0
#
# [5 rows x 23 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2300 entries, 0 to 2299
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   playlist_url       2300 non-null   object
#  1   year               2300 non-null   int64
#  2   track_id           2300 non-null   object
#  3   track_name         2300 non-null   object
#  4   track_popularity   2300 non-null   int64
#  5   album              2300 non-null   object
#  6   artist_id          2300 non-null   object
#  7   artist_name        2300 non-null   object
#  8   artist_genres      2300 non-null   object
#  9   artist_popularity  2300 non-null   int64
#  10  danceability       2299 non-null   float64
#  11  energy             2299 non-null   float64
#  12  key                2299 non-null   float64
#  13  loudness           2299 non-null   float64
#  14  mode               2299 non-null   float64
#  15  speechiness        2299 non-null   float64
#  16  acousticness       2299 non-null   float64
#  17  instrumentalness   2299 non-null   float64
#  18  liveness           2299 non-null   float64
#  19  valence            2299 non-null   float64
#  20  tempo              2299 non-null   float64
#  21  duration_ms        2299 non-null   float64
#  22  time_signature     2299 non-null   float64
# dtypes: float64(13), int64(3), object(7)
# memory usage: 413.4+ KB

# %%
data1.describe()
# Out:
#               year  track_popularity  artist_popularity  danceability  \
# count  2300.000000       2300.000000        2300.000000   2299.000000
# mean   2011.000000         70.943478          72.869565      0.660116
# std       6.634692         12.291526          12.179263      0.141137
# min    2000.000000          0.000000          29.000000      0.162000
# 25%    2005.000000         66.000000          65.000000      0.572000
# 50%    2011.000000         72.000000          74.000000      0.671000
# 75%    2017.000000         79.000000          82.000000      0.759500
# max    2022.000000        100.000000         100.000000      0.975000
#
#             energy          key     loudness         mode  speechiness  \
# count  2299.000000  2299.000000  2299.000000  2299.000000  2299.000000
# mean      0.693047     5.277947    -5.784040     0.598521     0.097795
# std       0.164838     3.628494     2.080853     0.490304     0.092445
# min       0.051900     0.000000   -21.107000     0.000000     0.022500
# 25%       0.586000     2.000000    -6.823500     0.000000     0.038000
# 50%       0.712000     5.000000    -5.511000     1.000000     0.056800
# 75%       0.820000     8.000000    -4.364500     1.000000     0.115500
# max       0.999000    11.000000    -0.276000     1.000000     0.576000
#
#        acousticness  instrumentalness     liveness      valence        tempo  \
# count   2299.000000       2299.000000  2299.000000  2299.000000  2299.000000
# mean       0.157689          0.013766     0.172618     0.535110   120.512450
# std        0.203844          0.083990     0.131620     0.227821    27.617729
# min        0.000013          0.000000     0.021000     0.037700    60.019000
# 25%        0.016500          0.000000     0.089950     0.360500    98.569500
# 50%        0.068900          0.000000     0.119000     0.540000   120.000000
# 75%        0.223000          0.000054     0.220000     0.722000   137.028000
# max        0.978000          0.985000     0.843000     0.974000   210.857000
#
#          duration_ms  time_signature
# count    2299.000000     2299.000000
# mean   226033.494128        3.982166
# std     42063.678588        0.219054
# min     97393.000000        1.000000
# 25%    200179.500000        4.000000
# 50%    221653.000000        4.000000
# 75%    245950.000000        4.000000
# max    688453.000000        5.000000

# %%
data1.shape
# Out:
# (2300, 23)

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\poornima\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\poornima\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\poornima\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: pillow in c:\users\poornima\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\poornima\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\poornima\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\poornima\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\poornima\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\poornima\anaconda3\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\poornima\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\poornima\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\poornima\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns

# %%
# histogram for year gives a better result if bins=10
data1.hist(bins=50, figsize=(15, 30))
plt.show()

# %%
features = [
    'track_popularity', 'danceability', 'energy', 'loudness', 
    'speechiness'
]
fig, axes = plt.subplots(nrows=1, ncols=len(features), figsize=(18, 6))
for i, attribute in enumerate(features):
    data1[[attribute]].boxplot(ax=axes[i])
    axes[i].set_title(attribute+' Box Plot')

plt.tight_layout()

plt.show()

# %%
category = data1['artist_genres'].unique()
wordcloud = WordCloud(width=800, height = 400, background_color = 'white').generate(' '.join(category))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Nominal Data')
plt.show()

# %%
top_artists = data1['artist_name'].value_counts().head(10)

# Create a bar chart to visualize the frequency of artist appearances
plt.figure(figsize=(12, 6))
top_artists.plot(kind='bar')
plt.xlabel('Artist Name')
plt.ylabel('Frequency')
plt.title('Top 10 Artists by Frequency of Appearances')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.show()

# %%
sorted_data1 = data1.sort_values(by='track_popularity', ascending=False)
data1_top_five = sorted_data1.head(5)
data1_top_five.plot(kind ="bar", x="track_popularity", y=["danceability", "energy"])
# Out:
# <Axes: xlabel='track_popularity'>

# %%
data1.plot(kind="scatter", x="loudness", y="track_popularity", alpha=0.2)
# Out:
# <Axes: xlabel='loudness', ylabel='track_popularity'>

# %%
data1.plot(kind="scatter", x="danceability", y="energy", alpha=0.2)
# Out:
# <Axes: xlabel='danceability', ylabel='energy'>

# %%
data1.plot(kind="scatter", x="tempo", y="track_popularity", alpha=0.2)
# Out:
# <Axes: xlabel='tempo', ylabel='track_popularity'>

# %%
data1.plot(kind="scatter", x="track_popularity", y="artist_popularity", alpha=0.2)
# Out:
# <Axes: xlabel='track_popularity', ylabel='artist_popularity'>

# %%
data1.plot(kind="scatter", x="acousticness", y="track_popularity", alpha=0.4,
    s=data1["artist_popularity"]/10, label="Popularity", figsize=(10,7),
    c="artist_popularity", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()

# %%
data1.plot(kind="scatter", x="energy", y="track_popularity",
    s=data1["artist_popularity"]/10, label="artist_popularity", figsize=(10,7), alpha=0.4, 
    c="artist_popularity", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()

# %%
data1.plot(kind="scatter", x="danceability", y="track_popularity",
    s=data1["artist_popularity"]/10, label="artist_popularity", figsize=(10,7), alpha=0.4, 
    c="artist_popularity", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()

# %%
incomplete_rows = data1[data1.isnull().any(axis=1)].head()
incomplete_rows
# Out:
#                                           playlist_url  year  \
# 447  https://open.spotify.com/playlist/37i9dQZF1DWT...  2004
#
#                    track_id   track_name  track_popularity      album  \
# 447  6MFQeWtk7kxWGydnJB2y36  These Words                68  Unwritten
#
#                   artist_id          artist_name  \
# 447  7o95ZoZt5ZYn31e9z1Hc0a  Natasha Bedingfield
#
#                              artist_genres  artist_popularity  ...  loudness  \
# 447  ['dance pop', 'pop', 'post-teen pop']                 64  ...       NaN
#
#      mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 447   NaN          NaN           NaN               NaN       NaN      NaN
#
#      tempo  duration_ms  time_signature
# 447    NaN          NaN             NaN
#
# [1 rows x 23 columns]

# %%
data1=data1.dropna()

# %%
data1.select_dtypes(include='number').corr()
# Out:
#                        year  track_popularity  artist_popularity  \
# year               1.000000          0.218524           0.463722
# track_popularity   0.218524          1.000000           0.331029
# artist_popularity  0.463722          0.331029           1.000000
# danceability       0.079579          0.006881           0.028621
# energy            -0.213265         -0.074284          -0.108966
# key               -0.012309         -0.047865          -0.029549
# loudness          -0.087451         -0.018558          -0.029041
# mode              -0.008052          0.019854          -0.044217
# speechiness        0.026364         -0.027161           0.048929
# acousticness       0.144010          0.058311           0.061085
# instrumentalness  -0.071127         -0.020854          -0.073707
# liveness          -0.027719         -0.020033           0.004202
# valence           -0.192476         -0.067300          -0.125514
# tempo              0.028505         -0.013565          -0.009967
# duration_ms       -0.340160         -0.043956          -0.024310
# time_signature    -0.016431         -0.038985          -0.010795
#
#                    danceability    energy       key  loudness      mode  \
# year                   0.079579 -0.213265 -0.012309 -0.087451 -0.008052
# track_popularity       0.006881 -0.074284 -0.047865 -0.018558  0.019854
# artist_popularity      0.028621 -0.108966 -0.029549 -0.029041 -0.044217
# danceability           1.000000 -0.040575  0.036666  0.028889 -0.123337
# energy                -0.040575  1.000000  0.004318  0.691206 -0.056107
# key                    0.036666  0.004318  1.000000  0.004074 -0.145893
# loudness               0.028889  0.691206  0.004074  1.000000 -0.026781
# mode                  -0.123337 -0.056107 -0.145893 -0.026781  1.000000
# speechiness            0.171114 -0.005981  0.008924 -0.038021 -0.069799
# acousticness          -0.105241 -0.543773 -0.010715 -0.414999  0.054809
# instrumentalness       0.018217  0.009142 -0.009785 -0.124393 -0.035061
# liveness              -0.084653  0.148944 -0.027931  0.084871 -0.023613
# valence                0.409612  0.388810  0.033535  0.307299 -0.071995
# tempo                 -0.193770  0.125645 -0.001949  0.092811  0.035134
# duration_ms           -0.105517 -0.040421 -0.007011 -0.082781  0.013255
# time_signature         0.086461  0.132879 -0.040845  0.073840 -0.005918
#
#                    speechiness  acousticness  instrumentalness  liveness  \
# year                  0.026364      0.144010         -0.071127 -0.027719
# track_popularity     -0.027161      0.058311         -0.020854 -0.020033
# artist_popularity     0.048929      0.061085         -0.073707  0.004202
# danceability          0.171114     -0.105241          0.018217 -0.084653
# energy               -0.005981     -0.543773          0.009142  0.148944
# key                   0.008924     -0.010715         -0.009785 -0.027931
# loudness             -0.038021     -0.414999         -0.124393  0.084871
# mode                 -0.069799      0.054809         -0.035061 -0.023613
# speechiness           1.000000     -0.037280         -0.056315  0.066531
# acousticness         -0.037280      1.000000          0.002361 -0.095045
# instrumentalness     -0.056315      0.002361          1.000000 -0.037942
# liveness              0.066531     -0.095045         -0.037942  1.000000
# valence               0.101180     -0.204592         -0.029367  0.034535
# tempo                 0.066760     -0.094712          0.024216  0.019186
# duration_ms           0.014558      0.000959          0.001424  0.013070
# time_signature        0.066111     -0.094030          0.013581  0.015489
#
#                     valence     tempo  duration_ms  time_signature
# year              -0.192476  0.028505    -0.340160       -0.016431
# track_popularity  -0.067300 -0.013565    -0.043956       -0.038985
# artist_popularity -0.125514 -0.009967    -0.024310       -0.010795
# danceability       0.409612 -0.193770    -0.105517        0.086461
# energy             0.388810  0.125645    -0.040421        0.132879
# key                0.033535 -0.001949    -0.007011       -0.040845
# loudness           0.307299  0.092811    -0.082781        0.073840
# mode              -0.071995  0.035134     0.013255       -0.005918
# speechiness        0.101180  0.066760     0.014558        0.066111
# acousticness      -0.204592 -0.094712     0.000959       -0.094030
# instrumentalness  -0.029367  0.024216     0.001424        0.013581
# liveness           0.034535  0.019186     0.013070        0.015489
# valence            1.000000 -0.020948    -0.137197        0.087011
# tempo             -0.020948  1.000000    -0.034604       -0.024924
# duration_ms       -0.137197 -0.034604     1.000000       -0.014692
# time_signature     0.087011 -0.024924    -0.014692        1.000000

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

data1_copy = data1.copy()

numeric_features = data1_copy.select_dtypes(include='number')
# Normalizing the data usign StandardScaler()
scaler = StandardScaler()
df_normalized = scaler.fit_transform(numeric_features)
data1_copy[numeric_features.columns] = df_normalized

# %%
data1.describe()
# Out:
#               year  track_popularity  artist_popularity  danceability  \
# count  2299.000000       2299.000000        2299.000000   2299.000000
# mean   2011.003045         70.944759          72.873423      0.660116
# std       6.634528         12.294047          12.180506      0.141137
# min    2000.000000          0.000000          29.000000      0.162000
# 25%    2005.000000         66.000000          65.000000      0.572000
# 50%    2011.000000         72.000000          74.000000      0.671000
# 75%    2017.000000         79.000000          82.000000      0.759500
# max    2022.000000        100.000000         100.000000      0.975000
#
#             energy          key     loudness         mode  speechiness  \
# count  2299.000000  2299.000000  2299.000000  2299.000000  2299.000000
# mean      0.693047     5.277947    -5.784040     0.598521     0.097795
# std       0.164838     3.628494     2.080853     0.490304     0.092445
# min       0.051900     0.000000   -21.107000     0.000000     0.022500
# 25%       0.586000     2.000000    -6.823500     0.000000     0.038000
# 50%       0.712000     5.000000    -5.511000     1.000000     0.056800
# 75%       0.820000     8.000000    -4.364500     1.000000     0.115500
# max       0.999000    11.000000    -0.276000     1.000000     0.576000
#
#        acousticness  instrumentalness     liveness      valence        tempo  \
# count   2299.000000       2299.000000  2299.000000  2299.000000  2299.000000
# mean       0.157689          0.013766     0.172618     0.535110   120.512450
# std        0.203844          0.083990     0.131620     0.227821    27.617729
# min        0.000013          0.000000     0.021000     0.037700    60.019000
# 25%        0.016500          0.000000     0.089950     0.360500    98.569500
# 50%        0.068900          0.000000     0.119000     0.540000   120.000000
# 75%        0.223000          0.000054     0.220000     0.722000   137.028000
# max        0.978000          0.985000     0.843000     0.974000   210.857000
#
#          duration_ms  time_signature
# count    2299.000000     2299.000000
# mean   226033.494128        3.982166
# std     42063.678588        0.219054
# min     97393.000000        1.000000
# 25%    200179.500000        4.000000
# 50%    221653.000000        4.000000
# 75%    245950.000000        4.000000
# max    688453.000000        5.000000

# %%
# Creating a dataset with lesser outliers
threshold = 3
outlier_mask = (np.abs(data1_copy.select_dtypes(include='number')) > threshold).any(axis=1)
data1_less_outliers = data1_copy.select_dtypes(include='number')[~outlier_mask]
data1=data1_less_outliers

# %%
# A Correlation Matrix for the dataset with lesser outliers
correlation_matrix=data1.corr()
#data1['duration_x_energy']=data1['duration_ms']*data1['energy']
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
# Our dataset did not contain any classes, hence, we added a feature with 2 classes.
# The feature 'popular' is based on 'track_popularity'.
# If 'track_popularity' is greater than 0.6, then 'popular' value equals 1, else 0.
data1['popular']=data1['track_popularity'].apply(lambda x:1 if x>0.6 else 0)

# %%
data1['popular'].value_counts()
# Out:
# 0    1451
# 1     509
# Name: popular, dtype: int64

# %%
# Combined 2 features to check which are most correlating
data1['duration_+_acousticness'] = data1['duration_ms'] + data1['acousticness'] 
data1['valence_+_energy'] = data1['valence'] + data1['energy'] 
data1['acousticness_+_energy'] = data1['acousticness'] + data1['valence_+_energy'] 
data1['acousticness_+_duration_ms'] = data1['acousticness'] - data1['duration_ms'] 

# Combined 3 features (just for experimenting)
data1['duration_+_energy_+_valence_+_energy'] = data1['duration_+_acousticness'] + data1['valence_+_energy'] 

# Combined 5 features
data1['du_+_va_+_en_+_ac_+_da'] = data1['duration_ms'] +  data1['valence'] + data1['energy'] +  data1['acousticness'] + data1['danceability'] 

# Combined 10 features
data1['10xFeatures'] = data1['duration_ms'] +  data1['valence'] + data1['energy'] +  data1['acousticness'] + data1['danceability'] + data1['artist_popularity'] + data1['key'] +data1['loudness']+ data1['liveness']+ data1['instrumentalness']

# Correlation matrix
correlation_matrix = data1.corr()
plt.figure(figsize=(14, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
# Dropped unnecessary columns
data1.drop(columns=['tempo','time_signature','mode'],inplace=True)
print(data1.columns)
correlation_matrix = data1.corr()
plt.figure(figsize=(14, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
# Out:
# Index(['year', 'track_popularity', 'artist_popularity', 'danceability',
#        'energy', 'key', 'loudness', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'duration_ms', 'popular',
#        'duration_+_acousticness', 'valence_+_energy', 'acousticness_+_energy',
#        'acousticness_+_duration_ms', 'duration_+_energy_+_valence_+_energy',
#        'du_+_va_+_en_+_ac_+_da', '10xFeatures'],
#       dtype='object')

# %%
# Created a dataset of the 2 best features out of the whole dataset
data_set1=pd.DataFrame(data1[['duration_ms','acousticness']])
data_set1
# Out:
#       duration_ms  acousticness
# 0        0.968731     -0.762019
# 2        0.582898      0.075127
# 3       -0.217658     -0.726739
# 4       -0.609530     -0.621636
# 5        0.658657     -0.189839
# ...           ...           ...
# 2293    -2.182345      0.919093
# 2294    -1.218668      2.611933
# 2295     0.308968      0.791517
# 2296    -1.272003     -0.551469
# 2299    -1.456478     -0.352744
#
# [1960 rows x 2 columns]

# %%
# Created a dataset of the 5 best features out of the whole dataset
data_set2=pd.DataFrame(data1[['duration_ms','valence','energy','acousticness','danceability']])
data_set2
# Out:
#       duration_ms   valence    energy  acousticness  danceability
# 0        0.968731 -1.098077 -0.194457     -0.762019     -1.637888
# 2        0.582898 -1.128809 -1.195657      0.075127     -0.929200
# 3       -0.217658 -0.593184  1.037323     -0.726739     -0.737855
# 4       -0.609530  1.430779  1.413531     -0.621636     -0.355164
# 5        0.658657  0.785394  1.182952     -0.189839      0.325176
# ...           ...       ...       ...           ...           ...
# 2293    -2.182345  1.531757 -1.019689      0.919093      1.260643
# 2294    -1.218668 -1.339547 -2.002685      2.611933     -0.121297
# 2295     0.308968 -0.760018  0.260634      0.791517      0.814170
# 2296    -1.272003  1.136624  0.606503     -0.551469      1.962244
# 2299    -1.456478 -1.458087 -0.218728     -0.352744     -2.013492
#
# [1960 rows x 5 columns]

# %%
# Created a dataset of the 10 best features out of the whole dataset
data_set3=pd.DataFrame(data1[['duration_ms','valence','energy','acousticness','danceability','artist_popularity','key','loudness','liveness','instrumentalness']])
data_set3
# Out:
#       duration_ms   valence    energy  acousticness  danceability  \
# 0        0.968731 -1.098077 -0.194457     -0.762019     -1.637888
# 2        0.582898 -1.128809 -1.195657      0.075127     -0.929200
# 3       -0.217658 -0.593184  1.037323     -0.726739     -0.737855
# 4       -0.609530  1.430779  1.413531     -0.621636     -0.355164
# 5        0.658657  0.785394  1.182952     -0.189839      0.325176
# ...           ...       ...       ...           ...           ...
# 2293    -2.182345  1.531757 -1.019689      0.919093      1.260643
# 2294    -1.218668 -1.339547 -2.002685      2.611933     -0.121297
# 2295     0.308968 -0.760018  0.260634      0.791517      0.814170
# 2296    -1.272003  1.136624  0.606503     -0.551469      1.962244
# 2299    -1.456478 -1.458087 -0.218728     -0.352744     -2.013492
#
#       artist_popularity       key  loudness  liveness  instrumentalness
# 0              1.077905  1.577321 -0.693597  0.466458         -0.162499
# 2             -0.975001  0.474695 -1.549202  0.595646         -0.163940
# 3              0.831557 -0.627931 -0.041319  0.276476         -0.163940
# 4             -0.646536  0.750351  0.452336 -0.687875         -0.149649
# 5             -1.385582 -0.903587 -0.564776 -0.779827         -0.162792
# ...                 ...       ...       ...       ...               ...
# 2293           0.174627  1.301664  1.068083 -0.725872         -0.163917
# 2294           2.227533 -1.454900 -2.861930 -0.437858         -0.163324
# 2295           1.077905 -1.179243 -1.099769 -0.346667         -0.150125
# 2296           0.995789  1.577321  0.650375  1.279583         -0.163940
# 2299           0.420975  0.474695  0.541261 -0.640000         -0.163940
#
# [1960 rows x 10 columns]

# %%
# Box Plot of the features given below.
# It can be noticed that the outliers in the 'track_popularity', 'danceability', 'energy' and 'loudness' 
# features have significantly decreased.
features = [
    'track_popularity', 'danceability', 'energy', 'loudness', 
    'speechiness'
]
fig, axes = plt.subplots(nrows=1, ncols=len(features), figsize=(18, 6))
for i, attribute in enumerate(features):
    data1[[attribute]].boxplot(ax=axes[i])
    axes[i].set_title(attribute+' Box Plot')

plt.tight_layout()

plt.show()

# %%
# No null values
data1.isna().sum()
# Out:
# year                                    0
# track_popularity                        0
# artist_popularity                       0
# danceability                            0
# energy                                  0
# key                                     0
# loudness                                0
# speechiness                             0
# acousticness                            0
# instrumentalness                        0
# liveness                                0
# valence                                 0
# duration_ms                             0
# popular                                 0
# duration_+_acousticness                 0
# valence_+_energy                        0
# acousticness_+_energy                   0
# acousticness_+_duration_ms              0
# duration_+_energy_+_valence_+_energy    0
# du_+_va_+_en_+_ac_+_da                  0
# 10xFeatures                             0
# dtype: int64

# %%
data1['track_popularity'].isnull().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
scaled_df = std_scaler.fit_transform(data1.select_dtypes(include='number'))
pca = PCA(n_components=3)
pca.fit_transform(scaled_df)
print(pca.components_)

df2 =pd.DataFrame(pca.fit_transform(scaled_df), columns =['PCA1','PCA2','PCA3'])

df1 = data1['track_popularity']

df2.index=df1.index #

result2 = pd.concat([df1,df2], axis=1)
print(result2)
# Out:
# [[ 0.14467633  0.08940353  0.06935344 -0.12022072 -0.28657229 -0.04037221
#   -0.21902156 -0.04029257  0.02976774 -0.01500737 -0.04328264 -0.34195155
#   -0.06743254  0.06710147 -0.02938861 -0.38477433 -0.37588356  0.06932976
#   -0.37837114 -0.37123236 -0.33691504]
#  [-0.38871271 -0.37202769 -0.28913219 -0.16143568 -0.03571834 -0.00820518
#   -0.10157878 -0.02366653 -0.06155537  0.04132818  0.00188627 -0.13769923
#    0.44308978 -0.3070684   0.2846979  -0.10888926 -0.14409646 -0.36493151
#    0.1036299   0.00894178 -0.12597022]
#  [ 0.06140243  0.14523194  0.14683367  0.14933579 -0.30401113  0.02196738
#   -0.22870794  0.07188725  0.50951514 -0.04139572 -0.09249829 -0.01371543
#    0.21775321  0.14216113  0.50872268 -0.1845035   0.08672505  0.18558196
#    0.19452338  0.23261479  0.12827673]]
#       track_popularity      PCA1      PCA2      PCA3
# 0             1.631652  2.522587  0.972738 -0.104250
# 2            -0.158221  3.507357  2.914636  0.262542
# 3             1.387578  0.666055 -0.652496 -1.117086
# 4             0.248568 -3.071418 -0.158813 -1.576950
# 5             0.167210 -2.657219  1.736375  0.206031
# ...                ...       ...       ...       ...
# 2293          1.224862 -0.222688 -5.003868  1.189172
# 2294          1.224862  5.596746 -2.951437  4.770060
# 2295          0.655357  0.715194 -1.394233  2.744189
# 2296         -0.158221 -2.397433 -2.981614 -0.834839
# 2299          0.492642  4.718636 -1.451176 -2.309278
#
# [1960 rows x 4 columns]

# %%
result2.isnull().sum()
# Out:
# track_popularity    0
# PCA1                0
# PCA2                0
# PCA3                0
# dtype: int64

# %%
from pandas.plotting import scatter_matrix

attributes = ["loudness", "valence", "acousticness", "liveness","danceability"]
scatter_matrix(data1[attributes], figsize=(12, 8))
# Out:
# array([[<Axes: xlabel='loudness', ylabel='loudness'>,
#         <Axes: xlabel='valence', ylabel='loudness'>,
#         <Axes: xlabel='acousticness', ylabel='loudness'>,
#         <Axes: xlabel='liveness', ylabel='loudness'>,
#         <Axes: xlabel='danceability', ylabel='loudness'>],
#        [<Axes: xlabel='loudness', ylabel='valence'>,
#         <Axes: xlabel='valence', ylabel='valence'>,
#         <Axes: xlabel='acousticness', ylabel='valence'>,
#         <Axes: xlabel='liveness', ylabel='valence'>,
#         <Axes: xlabel='danceability', ylabel='valence'>],
#        [<Axes: xlabel='loudness', ylabel='acousticness'>,
#         <Axes: xlabel='valence', ylabel='acousticness'>,
#         <Axes: xlabel='acousticness', ylabel='acousticness'>,
#         <Axes: xlabel='liveness', ylabel='acousticness'>,
#         <Axes: xlabel='danceability', ylabel='acousticness'>],
#        [<Axes: xlabel='loudness', ylabel='liveness'>,
#         <Axes: xlabel='valence', ylabel='liveness'>,
#         <Axes: xlabel='acousticness', ylabel='liveness'>,
#         <Axes: xlabel='liveness', ylabel='liveness'>,
#         <Axes: xlabel='danceability', ylabel='liveness'>],
#        [<Axes: xlabel='loudness', ylabel='danceability'>,
#         <Axes: xlabel='valence', ylabel='danceability'>,
#         <Axes: xlabel='acousticness', ylabel='danceability'>,
#         <Axes: xlabel='liveness', ylabel='danceability'>,
#         <Axes: xlabel='danceability', ylabel='danceability'>]],
#       dtype=object)
